# %% [markdown]
# # VGGT Seminar Project Overview
# Study the pretrained VGGT system across inputs, preserve every principal output, characterize strengths/failures, and assess targeted fine-tuning without reproducing full pretraining.

# %% [markdown]
# ## Assignment requirements
# 1. Run varied inputs. 2. Investigate strengths and weaknesses. 3. Attempt fine-tuning only if practical. 4. Produce a report or presentation.
#
# Paper: Wang et al., *VGGT: Visual Geometry Grounded Transformer*, CVPR 2025.

# %% [markdown]
# ## Planned workflow
# Environment validation → pin official code → import/checkpoint-free verification → approved checkpoint acquisition → official example → pilot experiments → analysis → fine-tuning decision → report.

# %%
# Safe: prints capabilities and writes a small JSON report; no downloads or inference.
# %run ../scripts/check_environment.py

# %% [markdown]
# ## Repository layout
# Reusable code is in `src/`, configs in `configs/`, immutable inputs in `data/`, generated artifacts in `outputs/`, third-party code in `external/`, evidence notes in `docs/`, and final assets in `report/`.

# %% [markdown]
# ## Future results
# - Official-example verification: pending
# - Runtime/VRAM baseline: pending
# - Diverse-input matrix: pending
# - Quantitative pilot: pending
# - Fine-tuning feasibility decision: pending
